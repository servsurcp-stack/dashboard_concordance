# %%
import pandas as pd
import numpy as np
import seaborn as sns
import openpyxl
import re

# %%
df = pd.read_excel("VERIFICATION DE CONCORDANCE DE CHARGEMENT.xlsx",engine="openpyxl", skiprows=[1,1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 25 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Id                                               568 non-null    int64
#  1   Heure de début                                   568 non-null    datetime64[ns]
#  2   Heure de fin                                     568 non-null    datetime64[ns]
#  3   Adresse de messagerie                            568 non-null    object
#  4   Nom                                              568 non-null    object
#  5   Date                                             568 non-null    datetime64[ns]
#  6   Nom de la personne en charge de la vérification  568 non-null    object
#  7   Lieu de la vérification                          568 non-null    object
#  8   Appartenance du conducteur                       568 non-null    object
#  9   Tournée / PDA / Nom de la société si DSP         568 non-null    object
#  10  Type de véhicule / immatriculation               568 non-null    object
#  11  Type de vérification                             568 non-null    object
#  12  REGION                                           568 non-null    object
#  13  AGENCES/ ANTENNES REGION EST                     266 non-null    object
#  14  AGENCES/ANTENNES REGION NORD                     95 non-null     object
#  15  AGENCES/ANTENNES REGION OUEST                    198 non-null    object
#  16  AGENCES/ANTENNES REGION SUD                      9 non-null      object
#  17  ANOMALIE                                         568 non-null    object
#  18  ANOMALIE DE CHARGEMENT                           373 non-null    object
#  19  Commentaires ( N° de colis...)                   73 non-null     object
#  20  ANOMALIE DE VEHICULE                             40 non-null     object
#  21  Commentaires                                     13 non-null     object
#  22  Matière dangereuse                               1 non-null      object
#  23  ANOMALIE SUIVI DE TOURNEE                        12 non-null     object
#  24  Commentaires divers                              43 non-null     object
# dtypes: datetime64[ns](3), int64(1), object(21)
# memory usage: 111.1+ KB

# %%
def extract_vehicle_info(value):
    if pd.isna(value):
        return pd.NA, pd.NA
    
    # Convertir en majuscule pour homogénéité
    value = str(value).upper().strip()
    
    # Expression régulière pour détecter les immatriculations (format XX-123-YY ou similaire)
    immat_pattern = r'[A-Z]{1,2}-?\d{2,3}-?[A-Z]{1,2}|[A-Z]{1,2}\d{2,3}[A-Z]{1,2}'
    
    # Chercher l'immatriculation dans la valeur
    immat_match = re.search(immat_pattern, value.replace(" ", ""))
    
    if immat_match:
        immat = immat_match.group(0)
        # Standardiser le format de l'immatriculation (ajouter des tirets si nécessaire)
        immat = immat.replace("-", "")  # Supprimer les tirets existants
        if len(immat) >= 5:  # Vérifier que l'immatriculation a assez de caractères
            immat_standard = f"{immat[:2]}-{immat[2:-2]}-{immat[-2:]}"
        else:
            immat_standard = immat
        
        # Extraire le type de véhicule (tout ce qui est avant l'immatriculation)
        type_vehicule = value.replace(immat_match.group(0), "").strip().replace("/", "").strip()
        if not type_vehicule:  # Si vide, assigner "INCONNU"
            type_vehicule = "INCONNU"
    else:
        # Si aucune immatriculation n'est trouvée, toute la valeur est le type de véhicule
        type_vehicule = value
        immat_standard = pd.NA
    
    return type_vehicule, immat_standard

# Fonction pour extraire tournée, PDA et nom de la société
def extract_tournee_pda_societe(value):
    if pd.isna(value):
        return pd.NA, pd.NA, pd.NA
    
    # Convertir en majuscule et nettoyer les espaces inutiles
    value = str(value).upper().strip()
    
    # Expression régulière pour capturer :
    # - Tournée : séquence de chiffres
    # - PDA : une seule lettre juste après la tournée (éventuellement séparée par un espace ou "/")
    # - Société : tout ce qui suit après la tournée et le PDA
    pattern = r'^(\d+)(?:[\s/]*([A-Z]))?(?:[\s/]*(.*))?$'
    match = re.match(pattern, value.replace("/", " ").strip())
    
    tournee = pd.NA
    pda = pd.NA
    societe = pd.NA
    
    if match:
        tournee = match.group(1)  # Numéro de tournée
        pda = match.group(2) if match.group(2) else pd.NA  # PDA (une seule lettre)
        societe = match.group(3) if match.group(3) else pd.NA  # Nom de la société
    else:
        # Si pas de match, considérer la valeur entière comme société ou tournée
        if re.match(r'^\d+$', value):
            tournee = value
        else:
            societe = value
    
    # Nettoyer la société (supprimer espaces multiples et barres obliques)
    if pd.notna(societe):
        societe = re.sub(r'\s+', ' ', societe.strip())
        if not societe:  # Si vide après nettoyage
            societe = pd.NA
    
    return tournee, pda, societe

# %%
def preprocessing(df):
    df["AGENCES/ANTENNES"] = ""
    for index, row in df.iterrows():
        if row["REGION"] == "REGION EST":
            df.at[index, "AGENCES/ANTENNES"] = row["AGENCES/ ANTENNES REGION EST"]
        elif row["REGION"] == "REGION NORD":
            df.at[index, "AGENCES/ANTENNES"] = row["AGENCES/ANTENNES REGION NORD"]
        elif row["REGION"] == "REGION OUEST":
            df.at[index, "AGENCES/ANTENNES"] = row["AGENCES/ANTENNES REGION OUEST"]
        elif row["REGION"] == "REGION SUD":
            df.at[index, "AGENCES/ANTENNES"] = row["AGENCES/ANTENNES REGION SUD"]
    
    # Supprimer les colonnes inutiles
    df = df.drop(columns=["AGENCES/ ANTENNES REGION EST", "AGENCES/ANTENNES REGION NORD", 
                          "AGENCES/ANTENNES REGION OUEST", "AGENCES/ANTENNES REGION SUD"])

    df["Nom"] = df["Nom"].str.upper()
    df["Nom"] = df["Nom"].str.replace("-", " ", regex=False)

    # Appliquer la fonction pour créer deux nouvelles colonnes
    df[["Type de véhicule", "Immatriculation"]] = df["Type de véhicule / immatriculation"].apply(
        lambda x: pd.Series(extract_vehicle_info(x))
    )
    
    # Supprimer la colonne originale
    df = df.drop(columns=["Type de véhicule / immatriculation"])
    
    # Mettre les colonnes en majuscule pour homogénéité
    df["Type de véhicule"] = df["Type de véhicule"].str.upper()
    df["Immatriculation"] = df["Immatriculation"].str.upper()

    
    # Appliquer la fonction pour créer trois nouvelles colonnes
    df[["Tournée", "PDA", "Nom de la société"]] = df["Tournée / PDA / Nom de la société si DSP"].apply(
        lambda x: pd.Series(extract_tournee_pda_societe(x))
    )
    
    # Standardiser : tout en majuscule
    df["PDA"] = df["PDA"].str.upper()
    df["Nom de la société"] = df["Nom de la société"].str.upper()
    
    df.drop(columns=["Matière dangereuse"],inplace=True)
    df.rename(columns={"ANOMALIE DE CHARGEMENT\xa0":"ANOMALIE DE CHARGEMENT"},inplace = True)
    df.rename(columns={"Commentaires divers\xa0":"Commentaires divers"},inplace = True)
    return df

df = preprocessing(df)

# %%
df
# Out:
#       Id      Heure de début        Heure de fin  \
# 0      1 2025-03-13 07:47:40 2025-03-13 07:50:12
# 1      2 2025-03-13 07:50:36 2025-03-13 07:53:42
# 2      3 2025-03-13 07:54:03 2025-03-13 07:56:11
# 3      4 2025-03-13 07:56:13 2025-03-13 07:58:01
# 4      5 2025-03-13 07:59:31 2025-03-13 08:02:14
# ..   ...                 ...                 ...
# 563  564 2025-10-03 10:47:11 2025-10-03 10:48:38
# 564  565 2025-10-04 08:28:13 2025-10-06 08:29:20
# 565  566 2025-10-06 09:36:30 2025-10-06 09:40:17
# 566  567 2025-10-06 09:40:19 2025-10-06 09:42:02
# 567  568 2025-10-06 09:42:04 2025-10-06 09:43:11
#
#                           Adresse de messagerie                       Nom  \
# 0    Jean.Christophe.REPIQUET@cevalogistics.com  JEAN CHRISTOPHE REPIQUET
# 1    Jean.Christophe.REPIQUET@cevalogistics.com  JEAN CHRISTOPHE REPIQUET
# 2    Jean.Christophe.REPIQUET@cevalogistics.com  JEAN CHRISTOPHE REPIQUET
# 3    Jean.Christophe.REPIQUET@cevalogistics.com  JEAN CHRISTOPHE REPIQUET
# 4    Jean.Christophe.REPIQUET@cevalogistics.com  JEAN CHRISTOPHE REPIQUET
# ..                                          ...                       ...
# 563             Jonathan.Canu@cevalogistics.com             JONATHAN CANU
# 564               Eric.Veaute@cevalogistics.com               ERIC VEAUTE
# 565             Jonathan.Canu@cevalogistics.com             JONATHAN CANU
# 566             Jonathan.Canu@cevalogistics.com             JONATHAN CANU
# 567             Jonathan.Canu@cevalogistics.com             JONATHAN CANU
#
#           Date Nom de la personne en charge de la vérification  \
# 0   2025-03-12                        Jean-Christophe REPIQUET
# 1   2025-03-12                        Jean-Christophe REPIQUET
# 2   2025-03-12                        Jean-Christophe REPIQUET
# 3   2025-03-12                        Jean-Christophe REPIQUET
# 4   2025-03-11                        Jean-Christophe REPIQUET
# ..         ...                                             ...
# 563 2025-10-03                                   Jonathan CANU
# 564 2025-10-04                                     Eric VEAUTE
# 565 2025-10-06                                   Jonathan CANU
# 566 2025-10-06                                   Jonathan CANU
# 567 2025-10-06                                   Jonathan CANU
#
#     Lieu de la vérification Appartenance du conducteur  \
# 0          Agence / Antenne                        DSP
# 1          Agence / Antenne                        DSP
# 2          Agence / Antenne                        DSP
# 3          Agence / Antenne                        DSP
# 4          Agence / Antenne                        DSP
# ..                      ...                        ...
# 563        Agence / Antenne                        DSP
# 564        Agence / Antenne                        DSP
# 565        Agence / Antenne                        DSP
# 566        Agence / Antenne                        DSP
# 567        Agence / Antenne                        DSP
#
#     Tournée / PDA / Nom de la société si DSP  ...  \
# 0             096320/C/JLH TRANSPORT EXPRESS  ...
# 1                  096363/F/TRANSPORT GNAGBO  ...
# 2                 096363/C/ TRANSPORT GNAGBO  ...
# 3                  096388/B/TRANSPORT AMRANI  ...
# 4                  079924/E/TRANSPORT O LOIN  ...
# ..                                       ...  ...
# 563                                  187889F  ...
# 564                           081306 / AJCT   ...
# 565                                  187507B  ...
# 566                                  189219B  ...
# 567                                  187578C  ...
#
#             ANOMALIE DE VEHICULE  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 563                          NaN
# 564                          NaN
# 565       Défaut de verrouillage
# 566                          NaN
# 567  Véhicule vitré;Etat général
#
#                                           Commentaires  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 563                                                NaN
# 564                                                NaN
# 565  Véhicules laissé ouvert, porte grandes ouverte...
# 566                                                NaN
# 567                                                NaN
#
#     ANOMALIE SUIVI DE TOURNEE Commentaires divers AGENCES/ANTENNES  \
# 0                         NaN                 NaN            CE09
# 1                         NaN                 NaN            CE09
# 2                         NaN                 NaN            CE09
# 3                         NaN                 NaN            CE09
# 4                         NaN                 NaN            CE07
# ..                        ...                 ...              ...
# 563                       NaN                 NaN           AT7801
# 564                       NaN                 NaN             CE08
# 565                       NaN                 NaN             CE18
# 566                       NaN                 NaN             CE18
# 567                       NaN                 NaN             CE18
#
#     Type de véhicule Immatriculation Tournée PDA      Nom de la société
# 0     RENAULT KANGOO       FJ-718-XX  096320   C  JLH TRANSPORT EXPRESS
# 1      RENAULTKANGOO       FA-578-LX  096363   F       TRANSPORT GNAGBO
# 2      RENAULTKANGOO       FA-428-LW  096363   C       TRANSPORT GNAGBO
# 3      RENAULTKANGOO       FD-456-WQ  096388   B       TRANSPORT AMRANI
# 4      RENAULTKANGOO       ER-099-MA  079924   E       TRANSPORT O LOIN
# ..               ...             ...     ...  ..                    ...
# 563          INCONNU       CM-701-NA  187889   F                   <NA>
# 564            SCUDO            <NA>  081306   A                    JCT
# 565          INCONNU       GW-416-DC  187507   B                   <NA>
# 566          INCONNU       GZ-907-YZ  189219   B                   <NA>
# 567          INCONNU       DJ-109-GE  187578   C                   <NA>
#
# [568 rows x 25 columns]

# %%
set(df.columns)
# Out:
# {'AGENCES/ANTENNES',
#  'ANOMALIE',
#  'ANOMALIE DE CHARGEMENT',
#  'ANOMALIE DE VEHICULE',
#  'ANOMALIE SUIVI DE TOURNEE',
#  'Adresse de messagerie',
#  'Appartenance du conducteur',
#  'Commentaires',
#  'Commentaires ( N° de colis...)',
#  'Commentaires divers',
#  'Date',
#  'Heure de début',
#  'Heure de fin',
#  'Id',
#  'Immatriculation',
#  'Lieu de la vérification',
#  'Nom',
#  'Nom de la personne en charge de la vérification',
#  'Nom de la société',
#  'PDA',
#  'REGION',
#  'Tournée',
#  'Tournée / PDA / Nom de la société si DSP',
#  'Type de véhicule',
#  'Type de vérification'}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 25 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Id                                               568 non-null    int64
#  1   Heure de début                                   568 non-null    datetime64[ns]
#  2   Heure de fin                                     568 non-null    datetime64[ns]
#  3   Adresse de messagerie                            568 non-null    object
#  4   Nom                                              568 non-null    object
#  5   Date                                             568 non-null    datetime64[ns]
#  6   Nom de la personne en charge de la vérification  568 non-null    object
#  7   Lieu de la vérification                          568 non-null    object
#  8   Appartenance du conducteur                       568 non-null    object
#  9   Tournée / PDA / Nom de la société si DSP         568 non-null    object
#  10  Type de vérification                             568 non-null    object
#  11  REGION                                           568 non-null    object
#  12  ANOMALIE                                         568 non-null    object
#  13  ANOMALIE DE CHARGEMENT                           373 non-null    object
#  14  Commentaires ( N° de colis...)                   73 non-null     object
#  15  ANOMALIE DE VEHICULE                             40 non-null     object
#  16  Commentaires                                     13 non-null     object
#  17  ANOMALIE SUIVI DE TOURNEE                        12 non-null     object
#  18  Commentaires divers                              43 non-null     object
#  19  AGENCES/ANTENNES                                 568 non-null    object
#  20  Type de véhicule                                 568 non-null    object
#  21  Immatriculation                                  505 non-null    object
#  22  Tournée                                          558 non-null    object
#  23  PDA                                              553 non-null    object
#  24  Nom de la société                                315 non-null    object
# dtypes: datetime64[ns](3), int64(1), object(21)
# memory usage: 111.1+ KB

# %%
for i in df.columns:
    print(" --------------------------------------------------------- ")
    print(i," doublons :", len(df) - df[i].nunique() )
    nan_percent = (df[i].isna().sum()/len(df[i]))*100
    print(i, f" % de NaN {nan_percent} %")
    print(df[i].value_counts())
    print("                                                           ")
# Out:
#  ---------------------------------------------------------
# Id  doublons : 0
# Id  % de NaN 0.0 %
# Id
# 1      1
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    1
# Name: count, Length: 568, dtype: int64
#
#  ---------------------------------------------------------
# Heure de début  doublons : 0
# Heure de début  % de NaN 0.0 %
# Heure de début
# 2025-03-13 07:47:40    1
# 2025-03-13 07:50:36    1
# 2025-03-13 07:54:03    1
# 2025-03-13 07:56:13    1
# 2025-03-13 07:59:31    1
#                       ..
# 2025-10-03 10:47:11    1
# 2025-10-04 08:28:13    1
# 2025-10-06 09:36:30    1
# 2025-10-06 09:40:19    1
# 2025-10-06 09:42:04    1
# Name: count, Length: 568, dtype: int64
#
#  ---------------------------------------------------------
# Heure de fin  doublons : 0
# Heure de fin  % de NaN 0.0 %
# Heure de fin
# 2025-03-13 07:50:12    1
# 2025-03-13 07:53:42    1
# 2025-03-13 07:56:11    1
# 2025-03-13 07:58:01    1
# 2025-03-13 08:02:14    1
#                       ..
# 2025-10-03 10:48:38    1
# 2025-10-06 08:29:20    1
# 2025-10-06 09:40:17    1
# 2025-10-06 09:42:02    1
# 2025-10-06 09:43:11    1
# Name: count, Length: 568, dtype: int64
#
#  ---------------------------------------------------------
# Adresse de messagerie  doublons : 565
# Adresse de messagerie  % de NaN 0.0 %
# Adresse de messagerie
# Jean.Christophe.REPIQUET@cevalogistics.com    285
# Jonathan.Canu@cevalogistics.com               267
# Eric.Veaute@cevalogistics.com                  16
# Name: count, dtype: int64
#
#  ---------------------------------------------------------
# Nom  doublons : 565
# Nom  % de NaN 0.0 %
# Nom
# JEAN CHRISTOPHE REPIQUET    285
# JONATHAN CANU               267
# ERIC VEAUTE                  16
# Name: count, dtype: int64
#
#  ---------------------------------------------------------
# Date  doublons : 434
# Date  % de NaN 0.0 %
# Date
# 2025-07-23    17
# 2025-09-18    15
# 2025-06-19    14
# 2025-06-18    14
# 2025-09-19    12
#               ..
# 2025-03-10     1
# 2025-03-03     1
# 2025-07-31     1
# 2025-08-28     1
# 2025-10-04     1
# Name: count, Length: 134, dtype: int64
#
#  ---------------------------------------------------------
# Nom de la personne en charge de la vérification  doublons : 565
# Nom de la personne en charge de la vérification  % de NaN 0.0 %
# Nom de la personne en charge de la vérification
# Jean-Christophe REPIQUET    283
# Jonathan CANU               267
# Eric VEAUTE                  18
# Name: count, dtype: int64
#
#  ---------------------------------------------------------
# Lieu de la vérification  doublons : 566
# Lieu de la vérification  % de NaN 0.0 %
# Lieu de la vérification
# Agence / Antenne    548
# Délocalisé           20
# Name: count, dtype: int64
#
#  ---------------------------------------------------------
# Appartenance du conducteur  doublons : 565
# Appartenance du conducteur  % de NaN 0.0 %
# Appartenance du conducteur
# DSP                      499
# COLIS PRIVE LIVRAISON     43
# COLIS PRIVE               26
# Name: count, dtype: int64
#
#  ---------------------------------------------------------
# Tournée / PDA / Nom de la société si DSP  doublons : 44
# Tournée / PDA / Nom de la société si DSP  % de NaN 0.0 %
# Tournée / PDA / Nom de la société si DSP
# 179426D                   3
# 187534A                   3
# 187803A                   3
# 187535B                   3
# 189219A                   2
#                          ..
# 159542C                   1
# 072693/D/SA TRANSPORTS    1
# 187541C                   1
# 079924/C/MKH              1
# 1457046/ CPL              1
# Name: count, Length: 524, dtype: int64
#
#  ---------------------------------------------------------
# Type de vérification  doublons : 565
# Type de vérification  % de NaN 0.0 %
# Type de vérification
# Après chargement    459
# Avant chargement     87
# Suivi de tournée     22
# Name: count, dtype: int64
#
#  ---------------------------------------------------------
# REGION  doublons : 564
# REGION  % de NaN 0.0 %
# REGION
# REGION EST      266
# REGION OUEST    198
# REGION NORD      95
# REGION SUD        9
# Name: count, dtype: int64
#
#  ---------------------------------------------------------
# ANOMALIE  doublons : 566
# ANOMALIE  % de NaN 0.0 %
# ANOMALIE
# Oui    402
# Non    166
# Name: count, dtype: int64
#
#  ---------------------------------------------------------
# ANOMALIE DE CHARGEMENT  doublons : 555
# ANOMALIE DE CHARGEMENT  % de NaN 34.33098591549296 %
# ANOMALIE DE CHARGEMENT
# Colis en cabine                                                                                                 277
# Colis non scanné (prévu pour ce chauffeur-livreur)                                                               33
# Colis en cabine;Colis non scanné (prévu pour ce chauffeur-livreur)                                               30
# Autre                                                                                                            11
# Colis en cabine;Autre                                                                                             6
# Colis non scanné (prévu pour ce chauffeur-livreur);Colis en cabine                                                4
# Adhésif Colis Privé dans le véhicule                                                                              3
# Colis non scanné (prévu pour ce chauffeur-livreur);Autre                                                          3
# Colis en cabine;Colis non scanné (prévu pour ce chauffeur-livreur);Colis non prévu pour ce chauffeur-livreur      2
# Colis non prévu pour ce chauffeur-livreur                                                                         1
# Colis en cabine;Adhésif Colis Privé dans le véhicule                                                              1
# Colis en cabine;Colis non scanné (prévu pour ce chauffeur-livreur);Autre                                          1
# Colis en cabine;Colis non prévu pour ce chauffeur-livreur                                                         1
# Name: count, dtype: int64
#
#  ---------------------------------------------------------
# Commentaires ( N° de colis...)  doublons : 495
# Commentaires ( N° de colis...)  % de NaN 87.14788732394366 %
# Commentaires ( N° de colis...)
# 1 COLIS AMAZON NON CHARGE SUR PDA  51002964814763000                                                                                                                                                                                  1
# 1 COLIS POUR TOURNEE  NON CHARGE SUR PDA R32609205824                                                                                                                                                                                 1
# 1 COLIS STATUT LIVRE BAL POUR AUTRE DSP SUITE DEPANNAGE ET OUBLI RENDRE COLIS . MAIL TRANSMIS  SUITE AUX VERIFICATIONS EFFECTUEES.                                                                                                    1
# SCOTCH CP RECUPERE  DANS CABINE . RAPPEL FAIT AU CHAUFFEUR                                                                                                                                                                            1
# COLIS YU000014503569006 STATUT LIVRE EN BAL MAIS DEPOSE SUR BLOC BAL. DA DEMANDE QUE COLIS SOIT RECUPERE ET RAMENE A L AGENCE.  COLIS  ZL2000566402 STATUT LIVRE BAL MAIS DEPOSE DEVANT PORTE APPARTEMENT SUR DEMANDE DESTINATAIRE    1
# Name: count, dtype: int64
#
#  ---------------------------------------------------------
# AGENCES/ANTENNES  doublons : 538
# AGENCES/ANTENNES  % de NaN 0.0 %
# AGENCES/ANTENNES
# CE18      101
# CE28       80
# CE07       47
# AT7801     42
# CE17       40
# CE26       36
# CE14       36
# CE15       31
# CE16       18
# AT2601     16
# CE03       13
# CE27       13
# AT4202     13
# AT7401     12
# CE09       10
# AT4201     10
# CE05        8
# AT0301      6
# CE01        6
# CE12        6
# AT6101      4
# CE21        4
# CE10        3
# AT6002      2
# CE02        2
# AT6001      2
# CE13        2
# CE20        2
# CE19        2
# CE08        1
# Name: count, dtype: int64
#
#  ---------------------------------------------------------
# Type de véhicule  doublons : 473
# Type de véhicule  % de NaN 0.0 %
# Type de véhicule
# INCONNU                    200
# X/X/X                       32
# RENAULT KANGOO              31
# KANGOO                      21
# RENAULT TRAFIC              20
#                           ...
# OPEL  COMBO                  1
# VOLKSWAGEN CRAFTER           1
# XX (PROBLÈME PHOTO TPH)      1
# RNEAULT KANGOO               1
# SCUDO                        1
# Name: count, Length: 95, dtype: int64
#
#  ---------------------------------------------------------
# Immatriculation  doublons : 155
# Immatriculation  % de NaN 11.091549295774648 %
# Immatriculation
# GL-742-JP    4
# GP-980-CS    4
# AB-201-ZH    4
# GV-535-XM    3
# ER-099-MA    3
#             ..
# EC-418-TT    1
# GY-872-HR    1
# FM-172-TZ    1
# FX-475-ZJ    1
# GX-119-CJ    1
# Name: count, Length: 413, dtype: int64
#
#  ---------------------------------------------------------
# Tournée  doublons : 309
# Tournée  % de NaN 1.7605633802816902 %
# Tournée
# 179426    13
# 149911    12
# 287133    12
# 280101    11
# 187535    10
#           ..
# 286921     1
# 289708     1
# 289706     1
# 187554     1
# 187860     1
# Name: count, Length: 259, dtype: int64
#
#  ---------------------------------------------------------
# PDA  doublons : 547
# PDA  % de NaN 2.640845070422535 %
# PDA
# C    113
# B    104
# A    100
# D     57
# E     38
# F     29
# G     22
# H     21
# I     14
# P     11
# J     11
# K     10
# T      5
# L      4
# O      3
# R      3
# M      2
# Y      2
# N      2
# V      1
# U      1
# Name: count, dtype: int64
#
#  ---------------------------------------------------------
# Nom de la société  doublons : 419
# Nom de la société  % de NaN 44.54225352112676 %
# Nom de la société
# OLIS PRIVE LIVRAISON                               24
# BENAYED TRANSPORT                                  20
# ALTRAL                                             12
# OLIS PRIVE                                          9
# BLACK PANTHER                                       8
#                                                    ..
# GELK TRANSPORTS SAS                                 1
# VEROMATRANS                                         1
# KING 78 TRANSPORT                                   1
# AR AVENUE OGISTICS SUIVI NAVETTE DIJON CHAUMONT     1
# JCT                                                 1
# Name: count, Length: 149, dtype: int64

# %%
df[["Commentaires ( N° de colis...)","Commentaires","Commentaires divers"]][0:50]
# Out:
#                        Commentaires ( N° de colis...)  \
# 0                                                 NaN
# 1   1 COLIS AMAZON NON CHARGE SUR PDA  51002964814...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   1 COLIS POUR TOURNEE  NON CHARGE SUR PDA R3260...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  1 COLIS STATUT LIVRE BAL POUR AUTRE DSP SUITE ...
# 12                                                NaN
# 13  SCOTCH CP RECUPERE  DANS CABINE . RAPPEL FAIT ...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  COLIS YU000014503569006 STATUT LIVRE EN BAL MA...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  Colis du même transporteur mais mauvaise tourn...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  LORS VISITE CHEZ DSP. CONTROLE D UN BOX DISPAT...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44           Nombreux colis devant. Remis à l'arrière
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                          Commentaires  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40  Présence d’un colis même tournée mais mauvais ...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45  Défaut de fermeture du cadenas de la porte arr...
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                   Commentaires divers
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  PATRON EN CHARGE DU COLIS A L ORIGINE A INDIQU...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  VERIFICATIONS PHYSIQUES DE PLUSIEURS COLIS LIV...
# 18                                                NaN
# 19                                                NaN
# 20              AUCUN ARRET SUR LA TOTALITE DU TRAJET
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  PATRON SA TRANSPORTS PRESENT LORS CONTROLE AVI...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  Véhicule non verrouillé durant la livraison ru...
# 38                              Pda 04A pour le flux
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49  SUIVI DE LA NAVETTE CE26/DSP BARRY SUITE DISPA...

# %%
df_Oui = df[df["ANOMALIE"] == "Oui"]

# %%
df_Oui.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 402 entries, 0 to 567
# Data columns (total 25 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Id                                               402 non-null    int64
#  1   Heure de début                                   402 non-null    datetime64[ns]
#  2   Heure de fin                                     402 non-null    datetime64[ns]
#  3   Adresse de messagerie                            402 non-null    object
#  4   Nom                                              402 non-null    object
#  5   Date                                             402 non-null    datetime64[ns]
#  6   Nom de la personne en charge de la vérification  402 non-null    object
#  7   Lieu de la vérification                          402 non-null    object
#  8   Appartenance du conducteur                       402 non-null    object
#  9   Tournée / PDA / Nom de la société si DSP         402 non-null    object
#  10  Type de vérification                             402 non-null    object
#  11  REGION                                           402 non-null    object
#  12  ANOMALIE                                         402 non-null    object
#  13  ANOMALIE DE CHARGEMENT                           373 non-null    object
#  14  Commentaires ( N° de colis...)                   73 non-null     object
#  15  ANOMALIE DE VEHICULE                             40 non-null     object
#  16  Commentaires                                     13 non-null     object
#  17  ANOMALIE SUIVI DE TOURNEE                        12 non-null     object
#  18  Commentaires divers                              32 non-null     object
#  19  AGENCES/ANTENNES                                 402 non-null    object
#  20  Type de véhicule                                 402 non-null    object
#  21  Immatriculation                                  358 non-null    object
#  22  Tournée                                          398 non-null    object
#  23  PDA                                              394 non-null    object
#  24  Nom de la société                                231 non-null    object
# dtypes: datetime64[ns](3), int64(1), object(21)
# memory usage: 81.7+ KB

# %%
df_anomalie  = df_Oui[["ANOMALIE DE CHARGEMENT", "ANOMALIE DE VEHICULE", "ANOMALIE SUIVI DE TOURNEE"]]

# %%
set(df_anomalie["ANOMALIE DE VEHICULE"])
# Out:
# {'Défaut de verrouillage',
#  'Défaut de verrouillage;Etat général',
#  'Etat général',
#  'Etat général;Manque séparation cabine/caisse',
#  'Manque séparation cabine/caisse',
#  'Manque séparation cabine/caisse;Etat général',
#  'Manque séparation cabine/caisse;Véhicule vitré',
#  'Manque séparation cabine/caisse;Véhicule vitré;Etat général',
#  'Passager non autorisé',
#  'Véhicule vitré;Etat général',
#  'Véhicule vitré;Manque séparation cabine/caisse',
#  nan}

# %%
set(df_anomalie["ANOMALIE SUIVI DE TOURNEE"])
# Out:
# {'Colis en cabine',
#  'Colis en cabine;Moteur tournant ou clef sur le contact;Défaut de verrouillage',
#  'Défaut de verrouillage;Colis en cabine',
#  'Défaut de verrouillage;Moteur tournant ou clef sur le contact;Colis en cabine',
#  nan}

# %%
set(df_anomalie["ANOMALIE DE CHARGEMENT"])
# Out:
# {'Adhésif Colis Privé dans le véhicule',
#  'Autre',
#  'Colis en cabine',
#  'Colis en cabine;Adhésif Colis Privé dans le véhicule',
#  'Colis en cabine;Autre',
#  'Colis en cabine;Colis non prévu pour ce chauffeur-livreur',
#  'Colis en cabine;Colis non scanné (prévu pour ce chauffeur-livreur)',
#  'Colis en cabine;Colis non scanné (prévu pour ce chauffeur-livreur);Autre',
#  'Colis en cabine;Colis non scanné (prévu pour ce chauffeur-livreur);Colis non prévu pour ce chauffeur-livreur',
#  'Colis non prévu pour ce chauffeur-livreur',
#  'Colis non scanné (prévu pour ce chauffeur-livreur)',
#  'Colis non scanné (prévu pour ce chauffeur-livreur);Autre',
#  'Colis non scanné (prévu pour ce chauffeur-livreur);Colis en cabine',
#  nan}

# %%
set(df_anomalie.columns)
# Out:
# {'ANOMALIE DE CHARGEMENT', 'ANOMALIE DE VEHICULE', 'ANOMALIE SUIVI DE TOURNEE'}

# %%
set(df["Appartenance du conducteur"])
# Out:
# {'COLIS PRIVE', 'COLIS PRIVE LIVRAISON', 'DSP'}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 25 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Id                                               568 non-null    int64
#  1   Heure de début                                   568 non-null    datetime64[ns]
#  2   Heure de fin                                     568 non-null    datetime64[ns]
#  3   Adresse de messagerie                            568 non-null    object
#  4   Nom                                              568 non-null    object
#  5   Date                                             568 non-null    datetime64[ns]
#  6   Nom de la personne en charge de la vérification  568 non-null    object
#  7   Lieu de la vérification                          568 non-null    object
#  8   Appartenance du conducteur                       568 non-null    object
#  9   Tournée / PDA / Nom de la société si DSP         568 non-null    object
#  10  Type de vérification                             568 non-null    object
#  11  REGION                                           568 non-null    object
#  12  ANOMALIE                                         568 non-null    object
#  13  ANOMALIE DE CHARGEMENT                           373 non-null    object
#  14  Commentaires ( N° de colis...)                   73 non-null     object
#  15  ANOMALIE DE VEHICULE                             40 non-null     object
#  16  Commentaires                                     13 non-null     object
#  17  ANOMALIE SUIVI DE TOURNEE                        12 non-null     object
#  18  Commentaires divers                              43 non-null     object
#  19  AGENCES/ANTENNES                                 568 non-null    object
#  20  Type de véhicule                                 568 non-null    object
#  21  Immatriculation                                  505 non-null    object
#  22  Tournée                                          558 non-null    object
#  23  PDA                                              553 non-null    object
#  24  Nom de la société                                315 non-null    object
# dtypes: datetime64[ns](3), int64(1), object(21)
# memory usage: 111.1+ KB

# %%
df[df["Immatriculation"] == ""]
# Out:
# Empty DataFrame
# Columns: [Id, Heure de début, Heure de fin, Adresse de messagerie, Nom, Date, Nom de la personne en charge de la vérification, Lieu de la vérification, Appartenance du conducteur, Tournée / PDA / Nom de la société si DSP, Type de vérification, REGION, ANOMALIE, ANOMALIE DE CHARGEMENT, Commentaires ( N° de colis...), ANOMALIE DE VEHICULE, Commentaires, ANOMALIE SUIVI DE TOURNEE, Commentaires divers, AGENCES/ANTENNES, Type de véhicule, Immatriculation, Tournée, PDA, Nom de la société]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Id', 'Heure de début', 'Heure de fin', 'Adresse de messagerie', 'Nom',
#        'Date', 'Nom de la personne en charge de la vérification',
#        'Lieu de la vérification', 'Appartenance du conducteur',
#        'Tournée / PDA / Nom de la société si DSP', 'Type de vérification',
#        'REGION', 'ANOMALIE', 'ANOMALIE DE CHARGEMENT',
#        'Commentaires ( N° de colis...)', 'ANOMALIE DE VEHICULE',
#        'Commentaires', 'ANOMALIE SUIVI DE TOURNEE', 'Commentaires divers',
#        'AGENCES/ANTENNES', 'Type de véhicule', 'Immatriculation', 'Tournée',
#        'PDA', 'Nom de la société'],
#       dtype='object')

# %%
set(df["AGENCES/ANTENNES"])
# Out:
# {'AT0301',
#  'AT2601',
#  'AT4201',
#  'AT4202',
#  'AT6001',
#  'AT6002',
#  'AT6101',
#  'AT7401',
#  'AT7801',
#  'CE01',
#  'CE02',
#  'CE03',
#  'CE05',
#  'CE07\xa0',
#  'CE08',
#  'CE09\xa0',
#  'CE10',
#  'CE12',
#  'CE13',
#  'CE14',
#  'CE15',
#  'CE16',
#  'CE17',
#  'CE18',
#  'CE19',
#  'CE20',
#  'CE21',
#  'CE26',
#  'CE27',
#  'CE28'}

# %%
df
# Out:
#       Id      Heure de début        Heure de fin  \
# 0      1 2025-03-13 07:47:40 2025-03-13 07:50:12
# 1      2 2025-03-13 07:50:36 2025-03-13 07:53:42
# 2      3 2025-03-13 07:54:03 2025-03-13 07:56:11
# 3      4 2025-03-13 07:56:13 2025-03-13 07:58:01
# 4      5 2025-03-13 07:59:31 2025-03-13 08:02:14
# ..   ...                 ...                 ...
# 563  564 2025-10-03 10:47:11 2025-10-03 10:48:38
# 564  565 2025-10-04 08:28:13 2025-10-06 08:29:20
# 565  566 2025-10-06 09:36:30 2025-10-06 09:40:17
# 566  567 2025-10-06 09:40:19 2025-10-06 09:42:02
# 567  568 2025-10-06 09:42:04 2025-10-06 09:43:11
#
#                           Adresse de messagerie                       Nom  \
# 0    Jean.Christophe.REPIQUET@cevalogistics.com  JEAN CHRISTOPHE REPIQUET
# 1    Jean.Christophe.REPIQUET@cevalogistics.com  JEAN CHRISTOPHE REPIQUET
# 2    Jean.Christophe.REPIQUET@cevalogistics.com  JEAN CHRISTOPHE REPIQUET
# 3    Jean.Christophe.REPIQUET@cevalogistics.com  JEAN CHRISTOPHE REPIQUET
# 4    Jean.Christophe.REPIQUET@cevalogistics.com  JEAN CHRISTOPHE REPIQUET
# ..                                          ...                       ...
# 563             Jonathan.Canu@cevalogistics.com             JONATHAN CANU
# 564               Eric.Veaute@cevalogistics.com               ERIC VEAUTE
# 565             Jonathan.Canu@cevalogistics.com             JONATHAN CANU
# 566             Jonathan.Canu@cevalogistics.com             JONATHAN CANU
# 567             Jonathan.Canu@cevalogistics.com             JONATHAN CANU
#
#           Date Nom de la personne en charge de la vérification  \
# 0   2025-03-12                        Jean-Christophe REPIQUET
# 1   2025-03-12                        Jean-Christophe REPIQUET
# 2   2025-03-12                        Jean-Christophe REPIQUET
# 3   2025-03-12                        Jean-Christophe REPIQUET
# 4   2025-03-11                        Jean-Christophe REPIQUET
# ..         ...                                             ...
# 563 2025-10-03                                   Jonathan CANU
# 564 2025-10-04                                     Eric VEAUTE
# 565 2025-10-06                                   Jonathan CANU
# 566 2025-10-06                                   Jonathan CANU
# 567 2025-10-06                                   Jonathan CANU
#
#     Lieu de la vérification Appartenance du conducteur  \
# 0          Agence / Antenne                        DSP
# 1          Agence / Antenne                        DSP
# 2          Agence / Antenne                        DSP
# 3          Agence / Antenne                        DSP
# 4          Agence / Antenne                        DSP
# ..                      ...                        ...
# 563        Agence / Antenne                        DSP
# 564        Agence / Antenne                        DSP
# 565        Agence / Antenne                        DSP
# 566        Agence / Antenne                        DSP
# 567        Agence / Antenne                        DSP
#
#     Tournée / PDA / Nom de la société si DSP  ...  \
# 0             096320/C/JLH TRANSPORT EXPRESS  ...
# 1                  096363/F/TRANSPORT GNAGBO  ...
# 2                 096363/C/ TRANSPORT GNAGBO  ...
# 3                  096388/B/TRANSPORT AMRANI  ...
# 4                  079924/E/TRANSPORT O LOIN  ...
# ..                                       ...  ...
# 563                                  187889F  ...
# 564                           081306 / AJCT   ...
# 565                                  187507B  ...
# 566                                  189219B  ...
# 567                                  187578C  ...
#
#             ANOMALIE DE VEHICULE  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 563                          NaN
# 564                          NaN
# 565       Défaut de verrouillage
# 566                          NaN
# 567  Véhicule vitré;Etat général
#
#                                           Commentaires  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 563                                                NaN
# 564                                                NaN
# 565  Véhicules laissé ouvert, porte grandes ouverte...
# 566                                                NaN
# 567                                                NaN
#
#     ANOMALIE SUIVI DE TOURNEE Commentaires divers AGENCES/ANTENNES  \
# 0                         NaN                 NaN            CE09
# 1                         NaN                 NaN            CE09
# 2                         NaN                 NaN            CE09
# 3                         NaN                 NaN            CE09
# 4                         NaN                 NaN            CE07
# ..                        ...                 ...              ...
# 563                       NaN                 NaN           AT7801
# 564                       NaN                 NaN             CE08
# 565                       NaN                 NaN             CE18
# 566                       NaN                 NaN             CE18
# 567                       NaN                 NaN             CE18
#
#     Type de véhicule Immatriculation Tournée PDA      Nom de la société
# 0     RENAULT KANGOO       FJ-718-XX  096320   C  JLH TRANSPORT EXPRESS
# 1      RENAULTKANGOO       FA-578-LX  096363   F       TRANSPORT GNAGBO
# 2      RENAULTKANGOO       FA-428-LW  096363   C       TRANSPORT GNAGBO
# 3      RENAULTKANGOO       FD-456-WQ  096388   B       TRANSPORT AMRANI
# 4      RENAULTKANGOO       ER-099-MA  079924   E       TRANSPORT O LOIN
# ..               ...             ...     ...  ..                    ...
# 563          INCONNU       CM-701-NA  187889   F                   <NA>
# 564            SCUDO            <NA>  081306   A                    JCT
# 565          INCONNU       GW-416-DC  187507   B                   <NA>
# 566          INCONNU       GZ-907-YZ  189219   B                   <NA>
# 567          INCONNU       DJ-109-GE  187578   C                   <NA>
#
# [568 rows x 25 columns]
